# %% [markdown]
# #Imports & Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import joblib
from pathlib import Path

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

# ── Fix random seeds for reproducibility
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

# ── Output directory for saving models and plots
OUT_DIR = Path("outputs")
OUT_DIR.mkdir(exist_ok=True)

print("Setup complete ✅")
# Out:
# Setup complete ✅

# %% [markdown]
# #Configuration
# ## All hyperparameters and settings are defined here in one place for easy tuning.

# %%
# ── File path
FILE_PATH     = "/content/drive/MyDrive/Colab Notebooks/electricity_demand_srilanka_fixed.csv"
TARGET_COL    = "Load Demand (kW)"      # column we want to predict
TIMESTAMP_COL = "Timestamp"             # datetime column

# ── Sequence parameters
LOOKBACK   = 96    # look back 96 steps = 24 hours (15-min intervals)
HORIZON    = 1     # predict 1 step ahead

# ── Train / validation / test split ratios
TRAIN_RATIO = 0.70
VAL_RATIO   = 0.15
# Test = remaining 15%

# ── Training hyperparameters
BATCH_SIZE  = 128
MAX_EPOCHS  = 100
LR          = 1e-3    # initial learning rate

# %% [markdown]
# #Load Data
# ## We load the CSV, sort by time, and remove data before 2022 to avoid COVID-period distortions in electricity usage patterns.

# %%
# ── Load CSV and parse timestamps
df = pd.read_csv(FILE_PATH, parse_dates=[TIMESTAMP_COL])
df = df.sort_values(TIMESTAMP_COL).reset_index(drop=True)
df = df.set_index(TIMESTAMP_COL)

# ── Remove COVID-period data (2020–2021) — abnormal consumption patterns
df = df[df.index >= "2022-01-01"]

print(f"Dataset shape : {df.shape}")
print(f"Date range    : {df.index[0]}  →  {df.index[-1]}")
df.head(3)
# Out:
# Dataset shape : (119712, 15)
# Date range    : 2022-01-01 00:00:00  →  2025-05-31 23:45:00
#                      Temperature (°C)  Humidity (%)  Wind Speed (m/s)  \
# Timestamp
# 2022-01-01 00:00:00         26.173471     72.951893          1.199782
# 2022-01-01 00:15:00         25.548488     79.667067          1.278307
# 2022-01-01 00:30:00         29.245336     73.951173          2.035820
#
#                      Rainfall (mm)  Solar Irradiance (W/m²)    GDP (LKR)  \
# Timestamp
# 2022-01-01 00:00:00      27.591119               307.117859   962.518129
# 2022-01-01 00:15:00      21.932563               253.800051   920.758076
# 2022-01-01 00:30:00       1.379579               259.287615  1069.472716
#
#                      Per Capita Energy Use (kWh)  Electricity Price (LKR/kWh)  \
# Timestamp
# 2022-01-01 00:00:00                   517.357808                    26.310040
# 2022-01-01 00:15:00                   488.698749                    35.674945
# 2022-01-01 00:30:00                   496.976531                    14.333373
#
#                      Day of Week  Hour of Day  Month  Season  Public Event  \
# Timestamp
# 2022-01-01 00:00:00            5            0      1  Summer             0
# 2022-01-01 00:15:00            5            0      1  Summer             0
# 2022-01-01 00:30:00            5            0      1  Summer             0
#
#                      Load Demand (kW)  Poya Day
# Timestamp
# 2022-01-01 00:00:00         1368.2253         0
# 2022-01-01 00:15:00         1345.8452         0
# 2022-01-01 00:30:00         1329.4014         0

# %% [markdown]
# # Feature Engineering
# ### We create two types of features:
#
# *   **Cyclic time features** — capture daily, weekly, and seasonal patterns using sin/cos encoding
# *   **Lag features** — past load values from 24h, 48h, and 1 week ago (safe: no leakage because all lags are ≥ 24h behind the target)

# %%
# ── Cyclic encoding for hour, day-of-week, and month
# Using sin/cos so that e.g. hour 23 and hour 0 are "close" to each other
df["sin_hour"]  = np.sin(2 * np.pi * df["Hour of Day"] / 24)
df["cos_hour"]  = np.cos(2 * np.pi * df["Hour of Day"] / 24)
df["sin_dow"]   = np.sin(2 * np.pi * df["Day of Week"] / 7)
df["cos_dow"]   = np.cos(2 * np.pi * df["Day of Week"] / 7)
df["sin_month"] = np.sin(2 * np.pi * df["Month"] / 12)
df["cos_month"] = np.cos(2 * np.pi * df["Month"] / 12)

# ── Binary weekend flag
df["is_weekend"] = (df["Day of Week"] >= 5).astype(int)

# ── Normalized year (trend signal: 0.0 = 2022, 1.0 = 2025)
df["year_norm"] = (df.index.year - 2022) / 3

# ── Lag features — all shifted ≥ 96 steps (24h) to prevent data leakage
df["load_lag_96"]  = df[TARGET_COL].shift(96)       # 24 hours ago
df["load_lag_192"] = df[TARGET_COL].shift(192)      # 48 hours ago
df["load_lag_672"] = df[TARGET_COL].shift(96 * 7)  # 1 week ago

# ── Rolling statistics anchored at 24h ago (no leakage)
df["load_mean_week"] = df[TARGET_COL].shift(96).rolling(96 * 7).mean()  # 7-day mean
df["load_std_day"]   = df[TARGET_COL].shift(96).rolling(96).std()       # 24h std

# ── Drop rows with NaN (from lag/rolling windows)
df.dropna(inplace=True)
print(f"Rows after dropna: {len(df):,}")
# Out:
# Rows after dropna: 118,945

# %%
# ── Define final feature list
FEATURE_COLS = [
    # Weather inputs
    "Temperature (°C)", "Humidity (%)", "Wind Speed (m/s)",
    "Rainfall (mm)", "Solar Irradiance (W/m²)",
    # Time features
    "sin_hour", "cos_hour", "sin_dow", "cos_dow",
    "sin_month", "cos_month", "is_weekend", "year_norm",
    # Calendar events
    "Public Event", "Poya Day",
    # Lag / rolling features
    "load_lag_96", "load_lag_192", "load_lag_672",
    "load_mean_week", "load_std_day",
]

# Keep only columns that actually exist in the dataframe
FEATURE_COLS = [c for c in FEATURE_COLS if c in df.columns]

print(f"Total features : {len(FEATURE_COLS)}")
print(f"Feature list   : {FEATURE_COLS}")
# Out:
# Total features : 20
# Feature list   : ['Temperature (°C)', 'Humidity (%)', 'Wind Speed (m/s)', 'Rainfall (mm)', 'Solar Irradiance (W/m²)', 'sin_hour', 'cos_hour', 'sin_dow', 'cos_dow', 'sin_month', 'cos_month', 'is_weekend', 'year_norm', 'Public Event', 'Poya Day', 'load_lag_96', 'load_lag_192', 'load_lag_672', 'load_mean_week', 'load_std_day']

# %% [markdown]
# # Leakage Sanity Check
# ### We check the Pearson correlation of each feature with the target. A correlation > 0.98 would suggest the feature is almost identical to the target — a sign of data leakage.
#
# Safe features have meaningful but not suspiciously perfect correlation.

# %%
print(f"{'Feature':<35}  Correlation with Target")
print("-" * 60)

for col in FEATURE_COLS:
    corr = df[col].corr(df[TARGET_COL])
    flag = "  ⚠️  POTENTIAL LEAKAGE" if abs(corr) > 0.98 else ""
    print(f"  {col:<35} {corr:+.4f}{flag}")
# Out:
# Feature                              Correlation with Target
# ------------------------------------------------------------
#   Temperature (°C)                    +0.0132
#   Humidity (%)                        +0.0021
#   Wind Speed (m/s)                    -0.0010
#   Rainfall (mm)                       -0.0077
#   Solar Irradiance (W/m²)             -0.0050
#   sin_hour                            +0.0743
#   cos_hour                            -0.7056
#   sin_dow                             +0.1854
#   cos_dow                             -0.2080
#   sin_month                           +0.3383
#   cos_month                           -0.0544
#   is_weekend                          -0.2469
#   year_norm                           +0.4981
#   Public Event                        -0.0751
#   Poya Day                            -0.1308
#   load_lag_96                         +0.8843
#   load_lag_192                        +0.8065
#   load_lag_672                        +0.9335
#   load_mean_week                      +0.5572
#   load_std_day                        -0.3027

# %% [markdown]
# # Temporal Split & Scaling
# ### **Important**: We use a **temporal (chronological) split** — never shuffle time-series data!
#
#
# *   Train: first 80%
# *   Validation: next 10%
# *   Test: final 10%
#
# Features and target are scaled **separately** with their own StandardScaler.

# %%
n       = len(df)
n_train = int(n * TRAIN_RATIO)
n_val   = int(n * VAL_RATIO)

# ── Chronological split
df_train = df.iloc[:n_train]
df_val   = df.iloc[n_train : n_train + n_val]
df_test  = df.iloc[n_train + n_val :]

print(f"Train : {len(df_train):,} samples  ({df_train.index[0].date()} → {df_train.index[-1].date()})")
print(f"Val   : {len(df_val):,} samples  ({df_val.index[0].date()} → {df_val.index[-1].date()})")
print(f"Test  : {len(df_test):,} samples  ({df_test.index[0].date()} → {df_test.index[-1].date()})")
# Out:
# Train : 83,261 samples  (2022-01-08 → 2024-05-25)
# Val   : 17,841 samples  (2024-05-25 → 2024-11-27)
# Test  : 17,843 samples  (2024-11-27 → 2025-05-31)

# %%
# ── Fit scalers on TRAINING data only, then apply to val/test
feat_scaler   = StandardScaler()
target_scaler = StandardScaler()

X_tr_raw = feat_scaler.fit_transform(df_train[FEATURE_COLS])
y_tr_raw = target_scaler.fit_transform(df_train[[TARGET_COL]])

X_vl_raw = feat_scaler.transform(df_val[FEATURE_COLS])     # transform only!
y_vl_raw = target_scaler.transform(df_val[[TARGET_COL]])

X_te_raw = feat_scaler.transform(df_test[FEATURE_COLS])
y_te_raw = target_scaler.transform(df_test[[TARGET_COL]])

# ── Save scalers for future inference
joblib.dump(feat_scaler,   OUT_DIR / "feat_scaler.pkl")
joblib.dump(target_scaler, OUT_DIR / "target_scaler.pkl")

print("Scalers saved ✅")
# Out:
# Scalers saved ✅

# %% [markdown]
# # Build Sliding-Window Sequences
# The model needs 3D input: `(samples, timesteps, features)`.
#
# We use a sliding window:
# - **X** = window of the past `LOOKBACK` (96) timesteps
# - **y** = the single next value (1 step ahead)

# %%
def build_sequences(X, y, lookback, horizon=1):
    """
    Convert flat arrays into overlapping windows.
    X shape: (samples, lookback, features)
    y shape: (samples, horizon)
    """
    Xs, ys = [], []
    for i in range(len(X) - lookback - horizon + 1):
        Xs.append(X[i : i + lookback])
        ys.append(y[i + lookback : i + lookback + horizon, 0])
    return np.array(Xs, dtype=np.float32), np.array(ys, dtype=np.float32)


X_tr, y_tr = build_sequences(X_tr_raw, y_tr_raw, LOOKBACK, HORIZON)
X_vl, y_vl = build_sequences(X_vl_raw, y_vl_raw, LOOKBACK, HORIZON)
X_te, y_te = build_sequences(X_te_raw, y_te_raw, LOOKBACK, HORIZON)

print(f"Train  X: {X_tr.shape}  y: {y_tr.shape}")
print(f"Val    X: {X_vl.shape}  y: {y_vl.shape}")
print(f"Test   X: {X_te.shape}  y: {y_te.shape}")

# ── Quick check: make sure target is not constant
assert y_tr.std() > 0.01, "❌ Target variance near zero — check sequence building!"
print(f"\nTarget stats — mean: {y_tr.mean():.4f}  std: {y_tr.std():.4f}  ✅")
# Out:
# Train  X: (83165, 96, 20)  y: (83165, 1)
# Val    X: (17745, 96, 20)  y: (17745, 1)
# Test   X: (17747, 96, 20)  y: (17747, 1)
#
# Target stats — mean: 0.0012  std: 0.9995  ✅

# %% [markdown]
# ## Build the CNN-LSTM Model
#
# **Why CNN + LSTM?**
#
# - **Conv1D** layers extract local short-term patterns (e.g., morning ramp-up, evening peak)
# - **LSTM** layers learn long-range temporal dependencies (e.g., daily/weekly seasonality)
# - **Causal padding** ensures each Conv1D output only depends on past timesteps (no future leakage)
#
# ```
# Input → Conv1D(64) → Conv1D(32) → LSTM(128) → LSTM(64) → Dense(64) → Dropout → Output
# ```

# %%
n_steps    = LOOKBACK             # 96 timesteps
n_features = X_tr.shape[2]       # number of input features

# ── Input layer
inp = Input(shape=(n_steps, n_features), name="input")

# ── CNN block: extract local temporal patterns
x = Conv1D(filters=64, kernel_size=3, padding="causal", activation="relu")(inp)
x = Conv1D(filters=32, kernel_size=3, padding="causal", activation="relu")(x)

# ── LSTM block: capture sequential dependencies
x = LSTM(128, return_sequences=True)(x)   # return all timesteps for next LSTM
x = LSTM(64,  return_sequences=False)(x)  # return only final hidden state

# ── Output block
x   = Dense(64, activation="relu")(x)
x   = Dropout(0.2)(x)                     # regularization — reduces overfitting
out = Dense(HORIZON)(x)                   # final forecast (1 value)

# ── Compile with MAE loss (robust to outliers)
model = Model(inp, out, name="CNN_LSTM_Forecaster")
model.compile(optimizer=Adam(LR), loss="mae", metrics=["mae"])

model.summary()
# Out:
# Model: "CNN_LSTM_Forecaster"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 96, 20)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 96, 64)         │         3,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 96, 32)         │         6,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 96, 128)        │        82,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 146,145 (570.88 KB)
#  Trainable params: 146,145 (570.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Train the Model
#
# We use three callbacks:
#
# | Callback | Purpose |
# |----------|---------|
# | `EarlyStopping` | Stop training when validation loss stops improving |
# | `ReduceLROnPlateau` | Halve learning rate when stuck |
# | `ModelCheckpoint` | Save the best model weights |

# %%
ckpt_path = str(OUT_DIR / "best_model.keras")

callbacks = [
    # Stop if val_loss doesn't improve for 15 epochs; restore best weights
    EarlyStopping(
        monitor="val_loss", patience=15,
        min_delta=1e-4, restore_best_weights=True, verbose=1
    ),
    # Reduce LR by 50% if val_loss plateaus for 8 epochs
    ReduceLROnPlateau(
        monitor="val_loss", factor=0.5,
        patience=8, min_lr=1e-5, verbose=1
    ),
    # Save best model to disk
    ModelCheckpoint(
        ckpt_path, monitor="val_loss",
        save_best_only=True, verbose=0
    ),
]

history = model.fit(
    X_tr, y_tr,
    validation_data=(X_vl, y_vl),
    epochs=MAX_EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=callbacks,
    shuffle=False,   # must NOT shuffle time-series data!
    verbose=1,
)
# Out:
# Epoch 1/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 0.1952 - mae: 0.1952 - val_loss: 0.4257 - val_mae: 0.4257 - learning_rate: 0.0010
# Epoch 2/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 19ms/step - loss: 0.1514 - mae: 0.1514 - val_loss: 0.3559 - val_mae: 0.3559 - learning_rate: 0.0010
# Epoch 3/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.1347 - mae: 0.1347 - val_loss: 0.3254 - val_mae: 0.3254 - learning_rate: 0.0010
# Epoch 4/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 21s 18ms/step - loss: 0.1251 - mae: 0.1251 - val_loss: 0.2849 - val_mae: 0.2849 - learning_rate: 0.0010
# Epoch 5/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 19ms/step - loss: 0.1209 - mae: 0.1209 - val_loss: 0.2237 - val_mae: 0.2237 - learning_rate: 0.0010
# Epoch 6/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.1156 - mae: 0.1156 - val_loss: 0.2133 - val_mae: 0.2133 - learning_rate: 0.0010
# Epoch 7/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 19s 17ms/step - loss: 0.1146 - mae: 0.1146 - val_loss: 0.1945 - val_mae: 0.1945 - learning_rate: 0.0010
# Epoch 8/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.1167 - mae: 0.1167 - val_loss: 0.1717 - val_mae: 0.1717 - learning_rate: 0.0010
# Epoch 9/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.1121 - mae: 0.1121 - val_loss: 0.1750 - val_mae: 0.1750 - learning_rate: 0.0010
# Epoch 10/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.1135 - mae: 0.1135 - val_loss: 0.1705 - val_mae: 0.1705 - learning_rate: 0.0010
# Epoch 11/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.1109 - mae: 0.1109 - val_loss: 0.1673 - val_mae: 0.1673 - learning_rate: 0.0010
# Epoch 12/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - loss: 0.1103 - mae: 0.1103 - val_loss: 0.1630 - val_mae: 0.1630 - learning_rate: 0.0010
# Epoch 13/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - loss: 0.1103 - mae: 0.1103 - val_loss: 0.1777 - val_mae: 0.1777 - learning_rate: 0.0010
# Epoch 14/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step - loss: 0.1106 - mae: 0.1106 - val_loss: 0.1650 - val_mae: 0.1650 - learning_rate: 0.0010
# Epoch 15/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 0.1100 - mae: 0.1100 - val_loss: 0.1480 - val_mae: 0.1480 - learning_rate: 0.0010
# Epoch 16/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - loss: 0.1085 - mae: 0.1085 - val_loss: 0.1530 - val_mae: 0.1530 - learning_rate: 0.0010
# Epoch 17/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - loss: 0.1098 - mae: 0.1098 - val_loss: 0.1483 - val_mae: 0.1483 - learning_rate: 0.0010
# Epoch 18/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.1114 - mae: 0.1114 - val_loss: 0.1489 - val_mae: 0.1489 - learning_rate: 0.0010
# Epoch 19/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.1091 - mae: 0.1091 - val_loss: 0.1505 - val_mae: 0.1505 - learning_rate: 0.0010
# Epoch 20/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.1102 - mae: 0.1102 - val_loss: 0.1463 - val_mae: 0.1463 - learning_rate: 0.0010
# Epoch 21/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.1092 - mae: 0.1092 - val_loss: 0.1546 - val_mae: 0.1546 - learning_rate: 0.0010
# Epoch 22/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 21s 19ms/step - loss: 0.1080 - mae: 0.1080 - val_loss: 0.1619 - val_mae: 0.1619 - learning_rate: 0.0010
# Epoch 23/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.1089 - mae: 0.1089 - val_loss: 0.1800 - val_mae: 0.1800 - learning_rate: 0.0010
# Epoch 24/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.1063 - mae: 0.1063 - val_loss: 0.1691 - val_mae: 0.1691 - learning_rate: 0.0010
# Epoch 25/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.1062 - mae: 0.1062 - val_loss: 0.1933 - val_mae: 0.1933 - learning_rate: 0.0010
# Epoch 26/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - loss: 0.1057 - mae: 0.1057 - val_loss: 0.1829 - val_mae: 0.1829 - learning_rate: 0.0010
# Epoch 27/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 21s 18ms/step - loss: 0.1066 - mae: 0.1066 - val_loss: 0.1961 - val_mae: 0.1961 - learning_rate: 0.0010
# Epoch 28/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1165 - mae: 0.1165
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - loss: 0.1065 - mae: 0.1065 - val_loss: 0.1912 - val_mae: 0.1912 - learning_rate: 0.0010
# Epoch 29/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - loss: 0.1065 - mae: 0.1065 - val_loss: 0.1007 - val_mae: 0.1007 - learning_rate: 5.0000e-04
# Epoch 30/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - loss: 0.1014 - mae: 0.1014 - val_loss: 0.0977 - val_mae: 0.0977 - learning_rate: 5.0000e-04
# Epoch 31/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.0992 - mae: 0.0992 - val_loss: 0.1042 - val_mae: 0.1042 - learning_rate: 5.0000e-04
# Epoch 32/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.0972 - mae: 0.0972 - val_loss: 0.1145 - val_mae: 0.1145 - learning_rate: 5.0000e-04
# Epoch 33/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.0964 - mae: 0.0964 - val_loss: 0.1222 - val_mae: 0.1222 - learning_rate: 5.0000e-04
# Epoch 34/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - loss: 0.0962 - mae: 0.0962 - val_loss: 0.1096 - val_mae: 0.1096 - learning_rate: 5.0000e-04
# Epoch 35/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - loss: 0.0946 - mae: 0.0946 - val_loss: 0.1036 - val_mae: 0.1036 - learning_rate: 5.0000e-04
# Epoch 36/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 22s 18ms/step - loss: 0.0944 - mae: 0.0944 - val_loss: 0.1084 - val_mae: 0.1084 - learning_rate: 5.0000e-04
# Epoch 37/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.0942 - mae: 0.0942 - val_loss: 0.0929 - val_mae: 0.0929 - learning_rate: 5.0000e-04
# Epoch 38/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.0923 - mae: 0.0923 - val_loss: 0.0940 - val_mae: 0.0940 - learning_rate: 5.0000e-04
# Epoch 39/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - loss: 0.0919 - mae: 0.0919 - val_loss: 0.0918 - val_mae: 0.0918 - learning_rate: 5.0000e-04
# Epoch 40/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.0912 - mae: 0.0912 - val_loss: 0.0899 - val_mae: 0.0899 - learning_rate: 5.0000e-04
# Epoch 41/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.0909 - mae: 0.0909 - val_loss: 0.0847 - val_mae: 0.0847 - learning_rate: 5.0000e-04
# Epoch 42/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.0905 - mae: 0.0905 - val_loss: 0.0862 - val_mae: 0.0862 - learning_rate: 5.0000e-04
# Epoch 43/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.0896 - mae: 0.0896 - val_loss: 0.0826 - val_mae: 0.0826 - learning_rate: 5.0000e-04
# Epoch 44/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - loss: 0.0900 - mae: 0.0900 - val_loss: 0.0830 - val_mae: 0.0830 - learning_rate: 5.0000e-04
# Epoch 45/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.0901 - mae: 0.0901 - val_loss: 0.0787 - val_mae: 0.0787 - learning_rate: 5.0000e-04
# Epoch 46/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 19ms/step - loss: 0.0907 - mae: 0.0907 - val_loss: 0.0774 - val_mae: 0.0774 - learning_rate: 5.0000e-04
# Epoch 47/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.0904 - mae: 0.0904 - val_loss: 0.0784 - val_mae: 0.0784 - learning_rate: 5.0000e-04
# Epoch 48/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.0902 - mae: 0.0902 - val_loss: 0.0850 - val_mae: 0.0850 - learning_rate: 5.0000e-04
# Epoch 49/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.0913 - mae: 0.0913 - val_loss: 0.0807 - val_mae: 0.0807 - learning_rate: 5.0000e-04
# Epoch 50/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 21s 19ms/step - loss: 0.0898 - mae: 0.0898 - val_loss: 0.0830 - val_mae: 0.0830 - learning_rate: 5.0000e-04
# Epoch 51/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 19ms/step - loss: 0.0892 - mae: 0.0892 - val_loss: 0.0828 - val_mae: 0.0828 - learning_rate: 5.0000e-04
# Epoch 52/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.0890 - mae: 0.0890 - val_loss: 0.0744 - val_mae: 0.0744 - learning_rate: 5.0000e-04
# Epoch 53/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.0895 - mae: 0.0895 - val_loss: 0.0816 - val_mae: 0.0816 - learning_rate: 5.0000e-04
# Epoch 54/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - loss: 0.0896 - mae: 0.0896 - val_loss: 0.0914 - val_mae: 0.0914 - learning_rate: 5.0000e-04
# Epoch 55/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.0914 - mae: 0.0914 - val_loss: 0.0963 - val_mae: 0.0963 - learning_rate: 5.0000e-04
# Epoch 56/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.0920 - mae: 0.0920 - val_loss: 0.0826 - val_mae: 0.0826 - learning_rate: 5.0000e-04
# Epoch 57/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 21s 19ms/step - loss: 0.0905 - mae: 0.0905 - val_loss: 0.0886 - val_mae: 0.0886 - learning_rate: 5.0000e-04
# Epoch 58/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.0911 - mae: 0.0911 - val_loss: 0.0878 - val_mae: 0.0878 - learning_rate: 5.0000e-04
# Epoch 59/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 21s 19ms/step - loss: 0.0892 - mae: 0.0892 - val_loss: 0.0897 - val_mae: 0.0897 - learning_rate: 5.0000e-04
# Epoch 60/100
# 649/650 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0912 - mae: 0.0912
# Epoch 60: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 19ms/step - loss: 0.0897 - mae: 0.0897 - val_loss: 0.0906 - val_mae: 0.0906 - learning_rate: 5.0000e-04
# Epoch 61/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.0930 - mae: 0.0930 - val_loss: 0.0840 - val_mae: 0.0840 - learning_rate: 2.5000e-04
# Epoch 62/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 21s 18ms/step - loss: 0.0911 - mae: 0.0911 - val_loss: 0.0763 - val_mae: 0.0763 - learning_rate: 2.5000e-04
# Epoch 63/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.0908 - mae: 0.0908 - val_loss: 0.0728 - val_mae: 0.0728 - learning_rate: 2.5000e-04
# Epoch 64/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.0898 - mae: 0.0898 - val_loss: 0.0738 - val_mae: 0.0738 - learning_rate: 2.5000e-04
# Epoch 65/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 20s 17ms/step - loss: 0.0885 - mae: 0.0885 - val_loss: 0.0738 - val_mae: 0.0738 - learning_rate: 2.5000e-04
# Epoch 66/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - loss: 0.0883 - mae: 0.0883 - val_loss: 0.0756 - val_mae: 0.0756 - learning_rate: 2.5000e-04
# Epoch 67/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.0881 - mae: 0.0881 - val_loss: 0.0740 - val_mae: 0.0740 - learning_rate: 2.5000e-04
# Epoch 68/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.0877 - mae: 0.0877 - val_loss: 0.0758 - val_mae: 0.0758 - learning_rate: 2.5000e-04
# Epoch 69/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.0873 - mae: 0.0873 - val_loss: 0.0741 - val_mae: 0.0741 - learning_rate: 2.5000e-04
# Epoch 70/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 19ms/step - loss: 0.0869 - mae: 0.0869 - val_loss: 0.0747 - val_mae: 0.0747 - learning_rate: 2.5000e-04
# Epoch 71/100
# 649/650 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0878 - mae: 0.0878
# Epoch 71: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - loss: 0.0864 - mae: 0.0864 - val_loss: 0.0770 - val_mae: 0.0770 - learning_rate: 2.5000e-04
# Epoch 72/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - loss: 0.0886 - mae: 0.0886 - val_loss: 0.0753 - val_mae: 0.0753 - learning_rate: 1.2500e-04
# Epoch 73/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.0877 - mae: 0.0877 - val_loss: 0.0733 - val_mae: 0.0733 - learning_rate: 1.2500e-04
# Epoch 74/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.0869 - mae: 0.0869 - val_loss: 0.0728 - val_mae: 0.0728 - learning_rate: 1.2500e-04
# Epoch 75/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.0866 - mae: 0.0866 - val_loss: 0.0731 - val_mae: 0.0731 - learning_rate: 1.2500e-04
# Epoch 76/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - loss: 0.0861 - mae: 0.0861 - val_loss: 0.0739 - val_mae: 0.0739 - learning_rate: 1.2500e-04
# Epoch 77/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - loss: 0.0856 - mae: 0.0856 - val_loss: 0.0747 - val_mae: 0.0747 - learning_rate: 1.2500e-04
# Epoch 78/100
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 21s 19ms/step - loss: 0.0856 - mae: 0.0856 - val_loss: 0.0738 - val_mae: 0.0738 - learning_rate: 1.2500e-04
# Epoch 78: early stopping
# Restoring model weights from the end of the best epoch: 63.

# %% [markdown]
# ## Evaluate the Model
#
# We evaluate on all three splits using four metrics:
#
# | Metric | Meaning |
# |--------|---------|
# | **MAE** | Mean Absolute Error — average error in kW |
# | **RMSE** | Root Mean Squared Error — penalizes large errors more |
# | **MAPE** | Mean Absolute Percentage Error — intuitive % error |
# | **R²** | Coefficient of determination — 1.0 = perfect fit |

# %%
# ── Reload the best saved weights
model.load_weights(ckpt_path)


def evaluate(X, y_scaled, split_name):
    """Predict, inverse-transform, and print metrics for a given split."""
    pred_scaled = model.predict(X, batch_size=BATCH_SIZE, verbose=0)

    # ── Inverse-transform back to original kW scale
    y_true = target_scaler.inverse_transform(y_scaled)
    y_pred = target_scaler.inverse_transform(pred_scaled)

    # ── Warn if predictions are nearly constant (bad sign)
    if y_pred.std() < 1.0:
        print(f"  ⚠️  [{split_name}] Predictions nearly constant — model may not have learned!")

    mae  = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mape = np.mean(np.abs((y_true - y_pred) / (y_true + 1e-8))) * 100
    r2   = r2_score(y_true, y_pred)

    print(f"  {split_name:6s} → MAE={mae:.2f} kW | RMSE={rmse:.2f} kW | MAPE={mape:.2f}% | R²={r2:.4f}")
    return y_true, y_pred


print("── Evaluation Results ──")
y_tr_true, y_tr_pred = evaluate(X_tr, y_tr, "Train")
y_vl_true, y_vl_pred = evaluate(X_vl, y_vl, "Val")
y_te_true, y_te_pred = evaluate(X_te, y_te, "Test")
# Out:
# ── Evaluation Results ──
#   Train  → MAE=25.11 kW | RMSE=36.52 kW | MAPE=1.42% | R²=0.9816
#   Val    → MAE=19.60 kW | RMSE=31.17 kW | MAPE=1.02% | R²=0.9823
#   Test   → MAE=18.88 kW | RMSE=27.39 kW | MAPE=0.89% | R²=0.9760

# %% [markdown]
# ## Visualize Results
#
# Three plots:
# 1. **Training curves** — loss over epochs
# 2. **Predictions vs actuals** — 7-day window on test set
# 3. **Scatter plot** — predicted vs actual (closer to diagonal = better)

# %%
# ── Plot 1: Training & Validation Loss Curves
fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(history.history["loss"],     label="Train MAE")
ax.plot(history.history["val_loss"], label="Validation MAE")
ax.set_title("Training Curves", fontsize=14)
ax.set_xlabel("Epoch")
ax.set_ylabel("MAE (scaled)")
ax.legend()
ax.grid(True, alpha=0.4)
fig.tight_layout()
fig.savefig(OUT_DIR / "training_curves.png", dpi=150)
plt.show()

# %%
# ── Plot 2: Actual vs Predicted — 7-day window on test set
n_plot = min(4 * 24 * 7, len(y_te_true))   # 7 days of 15-min intervals

fig, ax = plt.subplots(figsize=(16, 4))
ax.plot(y_te_true[:n_plot], label="Actual",    lw=1.2)
ax.plot(y_te_pred[:n_plot], label="Predicted", lw=1.0, alpha=0.85)
ax.set_title("Test Set — Actual vs Predicted (7 Days)", fontsize=14)
ax.set_xlabel("15-min intervals")
ax.set_ylabel("Load Demand (kW)")
ax.legend()
ax.grid(True, alpha=0.4)
fig.tight_layout()
fig.savefig(OUT_DIR / "test_predictions.png", dpi=150)
plt.show()

# %%
# ── Plot 3: Scatter — Actual vs Predicted
fig, ax = plt.subplots(figsize=(6, 6))
ax.scatter(y_te_true.flatten(), y_te_pred.flatten(),
           alpha=0.05, s=3, color="steelblue")

# Perfect prediction line
lims = [min(y_te_true.min(), y_te_pred.min()),
        max(y_te_true.max(), y_te_pred.max())]
ax.plot(lims, lims, "r--", lw=1.5, label="Perfect prediction")

ax.set_title("Actual vs Predicted — Test Set", fontsize=14)
ax.set_xlabel("Actual (kW)")
ax.set_ylabel("Predicted (kW)")
ax.legend()
ax.grid(True, alpha=0.4)
fig.tight_layout()
fig.savefig(OUT_DIR / "scatter.png", dpi=150)
plt.show()

# %% [markdown]
# ## Summary
#
# All outputs saved to the `outputs/` folder:
#
# | File | Description |
# |------|-------------|
# | `best_model.keras` | Trained model weights |
# | `feat_scaler.pkl` | Feature scaler (for inference) |
# | `target_scaler.pkl` | Target scaler (for inverse-transform) |
# | `training_curves.png` | Loss curves plot |
# | `test_predictions.png` | 7-day forecast vs actual |
# | `scatter.png` | Scatter plot of predictions |

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Reconstruct the original timestamps for the training predictions
# The y_tr_true and y_tr_pred arrays correspond to the target values from
# df_train starting after the LOOKBACK period.
# The index for these predictions should be from df_train starting at LOOKBACK + HORIZON - 1
start_idx_for_pred = LOOKBACK + HORIZON - 1
# The length of y_tr_true is len(df_train) - LOOKBACK - HORIZON + 1
# So the end index in df_train would be start_idx_for_pred + len(y_tr_true) = len(df_train)
train_prediction_timestamps = df_train.index[start_idx_for_pred : start_idx_for_pred + len(y_tr_true)]

# Create a DataFrame to hold actual and predicted values with their timestamps
df_train_predictions_actuals = pd.DataFrame({
    'Actual Load Demand (kW)': y_tr_true.flatten(),
    'Predicted Load Demand (kW)': y_tr_pred.flatten()
}, index=train_prediction_timestamps)

# Filter for the year 2022
df_2022_period = df_train_predictions_actuals[df_train_predictions_actuals.index.year == 2022]

if not df_2022_period.empty:
    print("Predicted and Actual Load Demand for a period in 2022 (from Training Data):")
    # Display the first few entries (e.g., first 5 days)
    print("\n--- First 5 days of 2022 in the training set ---")
    first_few_days = df_2022_period.head(5 * 24 * 4) # 5 days * 24 hours * 4 (15-min intervals)
    print(first_few_days.to_markdown(numalign="left", stralign="left"))

    # Display the last few entries (e.g., last 5 days)
    print("\n--- Last 5 days of 2022 in the training set ---")
    last_few_days = df_2022_period.tail(5 * 24 * 4)
    print(last_few_days.to_markdown(numalign="left", stralign="left"))

    # Plot a specific period in 2022, for example, the first week of predictions in 2022
    fig, ax = plt.subplots(figsize=(16, 4))
    plot_period_start = df_2022_period.index[0]
    plot_period_end = plot_period_start + pd.Timedelta(days=7)
    plot_data = df_2022_period.loc[plot_period_start : plot_period_end]

    if not plot_data.empty:
        ax.plot(plot_data.index, plot_data['Actual Load Demand (kW)'], label="Actual", lw=1.2)
        ax.plot(plot_data.index, plot_data['Predicted Load Demand (kW)'], label="Predicted", lw=1.0, alpha=0.85)
        ax.set_title(f"Actual vs Predicted Load Demand ({plot_period_start.strftime('%Y-%m-%d')} to {plot_period_end.strftime('%Y-%m-%d')})", fontsize=14)
        ax.set_xlabel("Timestamp")
        ax.set_ylabel("Load Demand (kW)")
        ax.legend()
        ax.grid(True, alpha=0.4)
        fig.tight_layout()
        plt.show()
    else:
        print("\nNo sufficient data to plot for the selected period in 2022.")

else:
    print("No predicted or actual data available for the year 2022 in the training set.")
# Out:
# Predicted and Actual Load Demand for a period in 2022 (from Training Data):
#
# --- First 5 days of 2022 in the training set ---
# | Timestamp           | Actual Load Demand (kW)   | Predicted Load Demand (kW)   |
# |:--------------------|:--------------------------|:-----------------------------|
# | 2022